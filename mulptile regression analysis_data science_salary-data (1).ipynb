# %% [markdown]
# Regression Analysis for Business Decision Making
#
# 1. Loading and Preparing the Data
# We will load the Salary_Data.csv dataset. For this example, we will consider 'YearsExperience' as our independent variable (feature) and 'Salary' as our dependent variable (target) to predict salary based on years of experience. Although the dataset is simple, it allows us to demonstrate the principles of regression analysis.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# Load the Salary_Data.csv dataset
df = pd.read_csv("B:\prof.simeon\data\Salary_Data.csv")

# Define features (X) and target (y) for regression
X = df[['YearsExperience']]  # Independent variable (feature)
y = df['Salary']              # Dependent variable (target)

display(df.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# 2. Visualizing the Data
# Let's visualize the relationship between 'YearsExperience' and 'Salary' using a scatter plot. This will help us see if there's a linear trend.
